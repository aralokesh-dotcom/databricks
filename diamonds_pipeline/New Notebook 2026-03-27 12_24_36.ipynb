# %%
# %sql
-- Create a simple UDF to calculate a 10% discount
CREATE OR REPLACE FUNCTION  broze_taxi.calculate_discount(price DOUBLE)
RETURNS DOUBLE
RETURN price * 0.9;
-- Usage
SELECT calculate_discount(100) AS discounted_price;

# %%
# %sql
create table database_dev.broze_taxi.test(id int,name string,age int)

# %%
print("hello git testing")

# %% [markdown]
# creating spark datafram

# %%
print("spark")

# %%
print(spark.version)
